# %%
import requests
import json

# %%
# Your API Key
api_key = "Your_API_KEY" # This is the key from your example

# The base URL for the API endpoint
url = "https://quizapi.io/api/v1/questions"

# Parameters to send with the request (equivalent to -d with -G in curl)
params = {
    "apiKey": api_key,
}

print(f"Requesting URL: {url} with params: {params}\n")

try:
    # Make the GET request
    response = requests.get(url, params=params)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()

        # Now 'data' holds the list of questions (like the output you provided)
        # You can print it to see, or process it further
        print("Successfully fetched data:")
        # For a more readable output:
        print(json.dumps(data, indent=2))

        # Example: Print the first question's text, if data is not empty
        if data and isinstance(data, list) and len(data) > 0:
            print(f"\n--- Example: First Question ---")
            first_question = data[0]
            print(f"ID: {first_question.get('id')}")
            print(f"Question: {first_question.get('question')}")
            print(f"Category: {first_question.get('category')}")
            print(f"Difficulty: {first_question.get('difficulty')}")
            # You can access other fields like 'answers', 'correct_answers', etc.
            # print(f"Answers: {first_question.get('answers')}")
        elif isinstance(data, dict) and data.get("error"): # Check for API specific error messages
             print(f"\nAPI Error: {data.get('error')}")
        else:
            print("\nNo questions returned or unexpected data format.")

    else:
        print(f"Error: Received status code {response.status_code}")
        print(f"Response content: {response.text}")

except requests.exceptions.RequestException as e:
    print(f"An error occurred during the request: {e}")
except json.JSONDecodeError:
    print("Failed to decode JSON from response.")
    print(f"Response content: {response.text}")
# Out:
# Requesting URL: https://quizapi.io/api/v1/questions with params: {'apiKey': '0Bh4rrJ78GlXKBuCcxYLJMQ1aKT6tqYe6e0wdega'}
#
# Successfully fetched data:
# [
#   {
#     "id": 9174,
#     "question": "Which PDO attribute should be set to use buffered queries, allowing the entire result set to be retrieved at once?",
#     "description": "Understanding how to enable buffered queries in PDO.",
#     "answers": {
#       "answer_a": "PDO::MYSQL_ATTR_USE_BUFFERED_QUERY",
#       "answer_b": "PDO::ATTR_BUFFER_MODE",
#       "answer_c": "PDO::MYSQL_ATTR_BUFFER_FETCH",
#       "answer_d": "PDO::FETCH_BUFFERED",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "true",
#       "answer_b_correct": "false",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "The `PDO::MYSQL_ATTR_USE_BUFFERED_QUERY` attribute enables buffered queries, allowing the entire result set to be stored in memory.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "PHP"
#       }
#     ],
#     "category": "Code",
#     "difficulty": "Hard"
#   },
#   {
#     "id": 8137,
#     "question": "How can you set a custom timeout for a wget download in seconds?",
#     "description": "Understanding how to set a custom timeout for wget downloads.",
#     "answers": {
#       "answer_a": "wget --timeout=30 url",
#       "answer_b": "wget --max-time=30 url",
#       "answer_c": "wget --limit-time=30 url",
#       "answer_d": "wget --time=30 url",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "true",
#       "answer_b_correct": "false",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "`wget --timeout=30 url` sets a 30-second timeout for the download.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "BASH"
#       }
#     ],
#     "category": "bash",
#     "difficulty": "Hard"
#   },
#   {
#     "id": 1994,
#     "question": "How can you remove all elements from a list in Python?",
#     "description": "Removing all elements from a list is useful when you need to clear the list for reuse.",
#     "answers": {
#       "answer_a": "list.delete()",
#       "answer_b": "list.clear()",
#       "answer_c": "list.remove_all()",
#       "answer_d": "list.reset()",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "false",
#       "answer_b_correct": "true",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "The 'clear()' method removes all elements from a list, making it empty.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "Python"
#       }
#     ],
#     "category": "Code",
#     "difficulty": "Easy"
#   },
#   {
#     "id": 5073,
#     "question": "How can you handle the same event being emitted multiple times rapidly?",
#     "description": "Debouncing rapid event emissions.",
#     "answers": {
#       "answer_a": "Use a debounce function to delay event handling",
#       "answer_b": "Use 'eventEmitter.setThrottle(eventName, delay)'",
#       "answer_c": "Register the listener with 'once()' instead of 'on()'",
#       "answer_d": "Emit the event only once using 'emitOnce()'",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "true",
#       "answer_b_correct": "false",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "To handle rapid event emissions, you can use a debounce function to delay the execution of the event handler.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "nodeJS"
#       }
#     ],
#     "category": "NodeJs",
#     "difficulty": "Medium"
#   },
#   {
#     "id": 7710,
#     "question": "Which command extracts the first word from a string?",
#     "description": "Understanding how to extract the first word in a string.",
#     "answers": {
#       "answer_a": "echo $str | awk '{print $1}'",
#       "answer_b": "cut -d' ' -f1 $str",
#       "answer_c": "${str%% *}",
#       "answer_d": "split($str, ' ')[0]",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "true",
#       "answer_b_correct": "false",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "Using `awk '{print $1}'` prints the first word from a string.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "BASH"
#       }
#     ],
#     "category": "bash",
#     "difficulty": "Easy"
#   },
#   {
#     "id": 9302,
#     "question": "Which function checks if a JSON string is valid in PHP?",
#     "description": "Understanding how to validate JSON data in PHP.",
#     "answers": {
#       "answer_a": "json_last_error()",
#       "answer_b": "is_json()",
#       "answer_c": "validate_json()",
#       "answer_d": "json_is_valid()",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "true",
#       "answer_b_correct": "false",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "The `json_last_error()` function checks if the last JSON operation was successful.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "PHP"
#       }
#     ],
#     "category": "Code",
#     "difficulty": "Easy"
#   },
#   {
#     "id": 4481,
#     "question": "What does the 'cluster.isWorker' property indicate in Node.js?",
#     "description": "Understanding cluster roles.",
#     "answers": {
#       "answer_a": "The process is a master",
#       "answer_b": "The process is a worker",
#       "answer_c": "The process is idle",
#       "answer_d": "The process is running on a different CPU core",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "false",
#       "answer_b_correct": "true",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "'cluster.isWorker' is true if the process is a worker in the Node.js cluster.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "nodeJS"
#       }
#     ],
#     "category": "NodeJs",
#     "difficulty": "Medium"
#   },
#   {
#     "id": 950,
#     "question": "What do you mean by \u201cRolling Update\u201d?",
#     "description": null,
#     "answers": {
#       "answer_a": "Rolling updates helps the user to replace an existing replica controller to newer one",
#       "answer_b": "Rolling updates helps the user to replace the node pool to a newer one",
#       "answer_c": null,
#       "answer_d": null,
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "true",
#       "answer_b_correct": "false",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": null,
#     "tip": null,
#     "tags": [
#       {
#         "name": "Kubernetes"
#       }
#     ],
#     "category": "DevOps",
#     "difficulty": "Medium"
#   },
#   {
#     "id": 9247,
#     "question": "Which PHP function checks if a file was uploaded via HTTP POST?",
#     "description": "Understanding how to verify if a file was uploaded using an HTML form.",
#     "answers": {
#       "answer_a": "is_uploaded_file()",
#       "answer_b": "file_is_uploaded()",
#       "answer_c": "checkUpload()",
#       "answer_d": "validate_upload()",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "true",
#       "answer_b_correct": "false",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "The `is_uploaded_file()` function checks if a file was uploaded via HTTP POST.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "PHP"
#       }
#     ],
#     "category": "Code",
#     "difficulty": "Medium"
#   },
#   {
#     "id": 1971,
#     "question": "What is the time complexity for accessing an element by index in a list?",
#     "description": "Time complexity represents the computational cost of an operation.",
#     "answers": {
#       "answer_a": "O(n)",
#       "answer_b": "O(1)",
#       "answer_c": "O(log n)",
#       "answer_d": "O(n^2)",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "false",
#       "answer_b_correct": "true",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "The time complexity for accessing an element by index in a list is O(1), which means it takes constant time.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "Python"
#       }
#     ],
#     "category": "Code",
#     "difficulty": "Easy"
#   },
#   {
#     "id": 7886,
#     "question": "Which operator is used to execute a second command only if the first command succeeds?",
#     "description": "Understanding conditional execution using exit status in Bash.",
#     "answers": {
#       "answer_a": "&&",
#       "answer_b": "||",
#       "answer_c": "|",
#       "answer_d": "&",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "true",
#       "answer_b_correct": "false",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "Using `command1 && command2` executes `command2` only if `command1` succeeds.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "BASH"
#       }
#     ],
#     "category": "bash",
#     "difficulty": "Easy"
#   },
#   {
#     "id": 7580,
#     "question": "Which method allows a loop to wait for a file to appear before processing it?",
#     "description": "Understanding event-driven loops in Bash.",
#     "answers": {
#       "answer_a": "while [ ! -f /path/to/file ]; do sleep 1; done",
#       "answer_b": "until file_exists /path/to/file; do sleep 1; done",
#       "answer_c": "for i in {1..10}; do check_file /path/to/file; done",
#       "answer_d": "loop until file_detected(/path/to/file) { sleep 1 }",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "true",
#       "answer_b_correct": "false",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "Using `while [ ! -f ]` ensures that the loop waits until the file appears.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "BASH"
#       }
#     ],
#     "category": "bash",
#     "difficulty": "Hard"
#   },
#   {
#     "id": 5971,
#     "question": "How does Vue's reactivity system handle changes to primitive values inside a 'ref()' object?",
#     "description": "Learning how changes to primitives are tracked in Vue's reactivity system.",
#     "answers": {
#       "answer_a": "Vue tracks changes to primitives inside 'ref()' by wrapping them in a reactive proxy and updating '.value'",
#       "answer_b": "Primitives cannot be reactive",
#       "answer_c": "Vue requires manual updates for primitives",
#       "answer_d": "Use 'computed()' for primitives",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "true",
#       "answer_b_correct": "false",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "Vue's reactivity system wraps primitives in a 'ref()' object, and changes are tracked by updating the '.value' property.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "VueJS"
#       }
#     ],
#     "category": "VueJS",
#     "difficulty": "Medium"
#   },
#   {
#     "id": 7750,
#     "question": "How do you reverse the words in a string while maintaining word order?",
#     "description": "Understanding word-level reversal in Bash.",
#     "answers": {
#       "answer_a": "echo \"$str\" | awk '{for(i=NF;i>0;i--) printf \"%s \", $i; print \"\"}'",
#       "answer_b": "rev_words $str",
#       "answer_c": "echo $str | awk '{print $NF, $(NF-1), $(NF-2)}'",
#       "answer_d": "cut -d' ' -f1 $str | tac",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "true",
#       "answer_b_correct": "false",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "Using `awk` can reverse words while preserving spaces.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "BASH"
#       }
#     ],
#     "category": "bash",
#     "difficulty": "Medium"
#   },
#   {
#     "id": 7435,
#     "question": "What is the purpose of the `else` statement in Bash?",
#     "description": "Understanding how `else` statements work in conditionals.",
#     "answers": {
#       "answer_a": "Executes if the `if` condition fails",
#       "answer_b": "Executes only when `if` is true",
#       "answer_c": "Always executes",
#       "answer_d": "Repeats the `if` condition",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "true",
#       "answer_b_correct": "false",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "The `else` block executes only if the `if` condition is false.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "BASH"
#       }
#     ],
#     "category": "bash",
#     "difficulty": "Easy"
#   },
#   {
#     "id": 4295,
#     "question": "What's the best way to handle feature flags in Next.js?",
#     "description": "Understanding feature management. (Medium)",
#     "answers": {
#       "answer_a": "Environment variables",
#       "answer_b": "Feature flag service with gradual rollout",
#       "answer_c": "Code comments",
#       "answer_d": "Multiple deployments",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "false",
#       "answer_b_correct": "true",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "Using a feature flag service with gradual rollout capabilities allows controlled feature releases while monitoring impact and managing user segments.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "Next.js"
#       }
#     ],
#     "category": "Next.js",
#     "difficulty": "Medium"
#   },
#   {
#     "id": 4133,
#     "question": "How would you properly update a theme or plugin in WordPress without losing customizations?",
#     "description": "Updating themes or plugins in WordPress.",
#     "answers": {
#       "answer_a": "By creating a child theme or custom plugin for modifications",
#       "answer_b": "By updating directly in the WordPress dashboard",
#       "answer_c": "By saving customizations in the theme options panel",
#       "answer_d": "By backing up and restoring after updates",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "true",
#       "answer_b_correct": "false",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "To avoid losing customizations, you should make changes in a child theme or a custom plugin, which preserves your modifications even after updates.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "WordPress"
#       }
#     ],
#     "category": "WordPress",
#     "difficulty": "Hard"
#   },
#   {
#     "id": 1395,
#     "question": "In Docker Compose, how does the `depends_on` option influence container startup?",
#     "description": "The `depends_on` option specifies the order in which Docker Compose starts containers.",
#     "answers": {
#       "answer_a": "It ensures that dependent services are healthy before starting",
#       "answer_b": "It specifies only the startup order but not readiness or health checks",
#       "answer_c": "It creates a network link between the dependent services",
#       "answer_d": "It forces Docker to restart containers upon failure",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "false",
#       "answer_b_correct": "true",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "The `depends_on` option only defines the startup order but does not check if services are ready or healthy.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "Docker"
#       }
#     ],
#     "category": "DevOps",
#     "difficulty": "Hard"
#   },
#   {
#     "id": 2368,
#     "question": "Which optimization technique best improves performance of COUNT(*) queries on large tables?",
#     "description": "Understanding aggregate optimization.",
#     "answers": {
#       "answer_a": "Create regular index",
#       "answer_b": "Maintain a counter table with triggers",
#       "answer_c": "Use materialized views",
#       "answer_d": "Full table scan",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "false",
#       "answer_b_correct": "true",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "Maintaining a counter table with triggers provides instant count results without scanning the main table, especially efficient for large tables with frequent COUNT(*) queries.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "Postgres"
#       }
#     ],
#     "category": "Postgres",
#     "difficulty": "Medium"
#   },
#   {
#     "id": 1825,
#     "question": "What happens when an object's reference count drops to zero?",
#     "description": "Understanding the effect of reference count on an object's lifecycle is important for memory management.",
#     "answers": {
#       "answer_a": "The object is moved to a cache",
#       "answer_b": "The object is deleted and memory is reclaimed",
#       "answer_c": "The object is copied",
#       "answer_d": "The object becomes a global variable",
#       "answer_e": null,
#       "answer_f": null
#     },
#     "multiple_correct_answers": "false",
#     "correct_answers": {
#       "answer_a_correct": "false",
#       "answer_b_correct": "true",
#       "answer_c_correct": "false",
#       "answer_d_correct": "false",
#       "answer_e_correct": "false",
#       "answer_f_correct": "false"
#     },
#     "correct_answer": null,
#     "explanation": "When an object's reference count drops to zero, it means that no references to the object exist, and the memory allocated to it can be reclaimed by the garbage collector.",
#     "tip": null,
#     "tags": [
#       {
#         "name": "Python"
#       }
#     ],
#     "category": "Code",
#     "difficulty": "Easy"
#   }
# ]
#
# --- Example: First Question ---
# ID: 9174
# Question: Which PDO attribute should be set to use buffered queries, allowing the entire result set to be retrieved at once?
# Category: Code
# Difficulty: Hard
